# %% [markdown]
# <a href="https://colab.research.google.com/github/violet417/violet417/blob/main/1%EA%B8%B0%EC%B4%88_32_%ED%96%89%EC%97%90_%EC%9E%88%EB%8A%94_%EA%B0%92%EC%9D%84_%EC%97%B4%EB%A1%9C_%EC%98%AC%EB%A6%AC%EB%8A%94_%EB%B0%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pibot_table: melt와는 반대로 행에 있는 값을 열로 올려서 새로운 열을 만드는 기능
df.pivot_table(
    index = 고정하고 싶은 열,
    columns = 열로 올리고 싶은 열, 
    values = 새로 올라간 열이 가지게 될 값, 
    dropna = True/False    # True: nan 값이 단 1개라도 있는 행은 삭제, False: nan 값도 포함
)

# %%
# 인덱스 새롭게 다시 만들기
df.reset_index()

# %%
import pandas as pd
# weather.csv 데이터 = 날씨 데이터(최고기온과 최저기온)
weather = pd.read_csv('weather.csv')
weather2 = pd.melt(weather, id_vars = ['id', 'year', 'month', 'element'], 
                   var_name = 'day', value_name = 'temp')
weather2
# Out:
#           id  year  month element  day  temp
# 0    MX17004  2010      1    tmax   d1   NaN
# 1    MX17004  2010      1    tmin   d1   NaN
# 2    MX17004  2010      2    tmax   d1   NaN
# 3    MX17004  2010      2    tmin   d1   NaN
# 4    MX17004  2010      3    tmax   d1   NaN
# ..       ...   ...    ...     ...  ...   ...
# 677  MX17004  2010     10    tmin  d31   NaN
# 678  MX17004  2010     11    tmax  d31   NaN
# 679  MX17004  2010     11    tmin  d31   NaN
# 680  MX17004  2010     12    tmax  d31   NaN
# 681  MX17004  2010     12    tmin  d31   NaN
#
# [682 rows x 6 columns]

# %%
weather3 = weather2.pivot_table(
    index = ['id', 'year', 'month', 'day'],
    columns = 'element', values = 'temp', dropna = False)
weather3
# Out:
# element                 tmax  tmin
# id      year month day
# MX17004 2010 1     d1    NaN   NaN
#                    d10   NaN   NaN
#                    d11   NaN   NaN
#                    d12   NaN   NaN
#                    d13   NaN   NaN
# ...                      ...   ...
#              12    d5    NaN   NaN
#                    d6   27.8  10.5
#                    d7    NaN   NaN
#                    d8    NaN   NaN
#                    d9    NaN   NaN
#
# [341 rows x 2 columns]

# %%
weather4 = weather3.reset_index()
weather4
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1   d1   NaN   NaN
# 1        MX17004  2010      1  d10   NaN   NaN
# 2        MX17004  2010      1  d11   NaN   NaN
# 3        MX17004  2010      1  d12   NaN   NaN
# 4        MX17004  2010      1  d13   NaN   NaN
# ..           ...   ...    ...  ...   ...   ...
# 336      MX17004  2010     12   d5   NaN   NaN
# 337      MX17004  2010     12   d6  27.8  10.5
# 338      MX17004  2010     12   d7   NaN   NaN
# 339      MX17004  2010     12   d8   NaN   NaN
# 340      MX17004  2010     12   d9   NaN   NaN
#
# [341 rows x 6 columns]

# %%
weather5 = weather2.pivot_table(
    index = ['id', 'year', 'month', 'day'],
    columns = 'element', values = 'temp', dropna = True)
weather5
# Out:
# element                 tmax  tmin
# id      year month day
# MX17004 2010 1     d30  27.8  14.5
#              2     d11  29.7  13.4
#                    d2   27.3  14.4
#                    d23  29.9  10.7
#                    d3   24.1  14.4
#              3     d10  34.5  16.8
#                    d16  31.1  17.6
#                    d5   32.1  14.2
#              4     d27  36.3  16.7
#              5     d27  33.2  18.2
#              6     d17  28.0  17.5
#                    d29  30.1  18.0
#              7     d3   28.6  17.5
#                    d14  29.9  16.5
#              8     d23  26.4  15.0
#                    d5   29.6  15.8
#                    d29  28.0  15.3
#                    d13  29.8  16.5
#                    d25  29.7  15.6
#                    d31  25.4  15.4
#                    d8   29.0  17.3
#              10    d5   27.0  14.0
#                    d14  29.5  13.0
#                    d15  28.7  10.5
#                    d28  31.2  15.0
# ...

# %%
weather6 = weather5.reset_index()
weather6
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1  d30  27.8  14.5
# 1        MX17004  2010      2  d11  29.7  13.4
# 2        MX17004  2010      2   d2  27.3  14.4
# 3        MX17004  2010      2  d23  29.9  10.7
# 4        MX17004  2010      2   d3  24.1  14.4
# 5        MX17004  2010      3  d10  34.5  16.8
# 6        MX17004  2010      3  d16  31.1  17.6
# 7        MX17004  2010      3   d5  32.1  14.2
# 8        MX17004  2010      4  d27  36.3  16.7
# 9        MX17004  2010      5  d27  33.2  18.2
# 10       MX17004  2010      6  d17  28.0  17.5
# 11       MX17004  2010      6  d29  30.1  18.0
# 12       MX17004  2010      7   d3  28.6  17.5
# 13       MX17004  2010      7  d14  29.9  16.5
# 14       MX17004  2010      8  d23  26.4  15.0
# 15       MX17004  2010      8   d5  29.6  15.8
# 16       MX17004  2010      8  d29  28.0  15.3
# 17       MX17004  2010      8  d13  29.8  16.5
# 18       MX17004  2010      8  d25  29.7  15.6
# ...
